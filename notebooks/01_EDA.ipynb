# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
ratings = pd.read_csv('../ml-25m/ratings.csv')
movies = pd.read_csv('../ml-25m/movies.csv')

# %%
ratings.head()
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print("Ratings shape:", ratings.shape)
print("Movies shape:", movies.shape)
# Out:
# Ratings shape: (25000095, 4)
# Movies shape: (62423, 3)

# %%
ratings.isnull().sum()
movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.500010e+07  2.500010e+07  2.500010e+07  2.500010e+07
# mean   8.118928e+04  2.138798e+04  3.533854e+00  1.215601e+09
# std    4.679172e+04  3.919886e+04  1.060744e+00  2.268758e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    4.051000e+04  1.196000e+03  3.000000e+00  1.011747e+09
# 50%    8.091400e+04  2.947000e+03  3.500000e+00  1.198868e+09
# 75%    1.215570e+05  8.623000e+03  4.000000e+00  1.447205e+09
# max    1.625410e+05  2.091710e+05  5.000000e+00  1.574328e+09

# %%
print("Users:", ratings['userId'].nunique())
print("Movies:", ratings['movieId'].nunique())
print("Ratings:", len(ratings))
# Out:
# Users: 162541
# Movies: 59047
# Ratings: 25000095

# %%
plt.figure(figsize=(8,5))

ratings['rating'].hist(
    bins=10
)

plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")

plt.show()

# %%
user_counts = ratings.groupby('userId').size()

user_counts.sort_values(
    ascending=False
).head(10)
# Out:
# userId
# 72315     32202
# 80974      9178
# 137293     8913
# 33844      7919
# 20055      7488
# 109731     6647
# 92046      6564
# 49403      6553
# 30879      5693
# 115102     5649
# dtype: int64

# %%
movie_counts = ratings.groupby('movieId').size()

movie_counts.sort_values(
    ascending=False
).head(10)
# Out:
# movieId
# 356     81491
# 318     81482
# 296     79672
# 593     74127
# 2571    72674
# 260     68717
# 480     64144
# 527     60411
# 110     59184
# 2959    58773
# dtype: int64

# %%
num_users = ratings['userId'].nunique()
num_movies = ratings['movieId'].nunique()

num_possible = num_users * num_movies
num_actual = len(ratings)

sparsity = 1 - (num_actual / num_possible)

print(f"Sparsity: {sparsity:.6f}")
# Out:
# Sparsity: 0.997395

# %% [markdown]
# # Day 1 — Environment Setup & Exploratory Data Analysis (EDA)
#
# ## Objective
#
# Set up the development environment, load the MovieLens 25M dataset, perform initial exploratory data analysis, and evaluate dataset sparsity for collaborative filtering.
#
# ---
#
# ## Tasks Completed
#
# ### 1. Environment Setup
#
# * Created Python virtual environment (`.venv`)
# * Installed required libraries:
#
#   * pandas
#   * numpy
#   * matplotlib
#   * seaborn
#   * scipy
#   * scikit-learn
#   * tqdm
#   * jupyter
# * Generated `requirements.txt`
#
# ### 2. Dataset Loading
#
# Loaded:
#
# * ratings.csv
# * movies.csv
#
# Dataset source:
#
# * MovieLens 25M Dataset
#
# ### 3. Exploratory Data Analysis
#
# Performed:
#
# * Dataset shape inspection
# * Missing value checks
# * Basic statistical summary
# * Unique user count analysis
# * Unique movie count analysis
# * Rating distribution analysis
# * Most active users analysis
# * Most rated movies analysis
#
# ### 4. Sparsity Analysis
#
# Computed matrix sparsity using:
#
# Sparsity = 1 - (Actual Ratings / Possible Ratings)
#
# Result:
#
# * Sparsity = 0.997395
# * Approximately 99.74% of the user-item matrix is empty.
#
# ### Key Observation
#
# The dataset is highly sparse, making sparse matrix representations and matrix factorization techniques such as Singular Value Decomposition (SVD) necessary.
#
# ---
#
# ## Deliverables Produced
#
# * Working Jupyter environment
# * EDA notebook (`01_EDA.ipynb`)
# * Installed project dependencies
# * Dataset understanding and statistics
# * Sparsity calculation
#
# ---
#
# ## Status
#
# Day 1: COMPLETED ✅
#
# Next Stage:
# Day 2 — User-Item Matrix Construction
